# %%
import pandas as  pd

# %%
data=pd.read_csv(r'/content/drive/MyDrive/Daily_Public_Transport_Passenger_Boardings_By_Ticket_Type_20240513 (2).csv')

# %%
data.head()
# Out:
#          Date  MyWay  Paper Ticket
# 0  01/07/2019  66215          4325
# 1  15/09/2023  63800          7349
# 2  28/12/2021   9994          1882
# 3  11/01/2023  43769          3991
# 4  11/09/2021   3810           685

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
data.head()
# Out:
#         Date  MyWay  Paper Ticket
# 0 2019-07-01  66215          4325
# 1 2023-09-15  63800          7349
# 2 2021-12-28   9994          1882
# 3 2023-01-11  43769          3991
# 4 2021-09-11   3810           685

# %%
data.set_index('Date',inplace=True)
data.head()
# Out:
#             MyWay  Paper Ticket
# Date
# 2019-07-01  66215          4325
# 2023-09-15  63800          7349
# 2021-12-28   9994          1882
# 2023-01-11  43769          3991
# 2021-09-11   3810           685

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
sd='2023-04-01'
ed='2024-04-30'
data=data[data.index>=sd]

# %%
data=data[data.index<=ed]

# %%
data
# Out:
#             MyWay  Paper Ticket
# Date
# 2023-09-15  63800          7349
# 2023-08-29  69155          6507
# 2023-04-11  50246          4306
# 2023-09-17  19207          2368
# 2023-10-07  24249          3089
# ...           ...           ...
# 2024-03-20  76782          1346
# 2023-07-13  49311          4309
# 2024-04-14  18001          2844
# 2023-08-16  70115          6955
# 2023-07-26  69067          6811
#
# [396 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(17,5))
plt.plot(data.index,data['MyWay'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(17,5))

plt.plot(data.index,data['Paper Ticket'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
roughdata=data.tail(10)
plt.plot(roughdata.index,roughdata['Paper Ticket'])

# %%
import seaborn as sns
sns.scatterplot(data['MyWay'])
# Out:
# <Axes: xlabel='Date', ylabel='MyWay'>

# %%
import seaborn as sns
sns.scatterplot(data['Paper Ticket'])
# Out:
# <Axes: xlabel='Date', ylabel='Paper Ticket'>

# %%
plt.boxplot(data['MyWay'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ff387182b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ff38e2cc10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ff391df3a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78ff38f43e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78ff38f40040>],
#  'means': []}

# %%
plt.boxplot(data['Paper Ticket'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ff385b8dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ff385b9300>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ff385b8b20>],
#  'medians': [<matplotlib.lines.Line2D at 0x78ff385b9840>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78ff385b9ae0>],
#  'means': []}

# %%
data['MyWay'].describe()
# Out:
# count      396.000000
# mean     48324.664141
# std      21774.787575
# min       2345.000000
# 25%      23246.250000
# 50%      56824.000000
# 75%      66537.750000
# max      79279.000000
# Name: MyWay, dtype: float64

# %%
data['Paper Ticket'].describe()
# Out:
# count      396.000000
# mean      4789.712121
# std       2541.356289
# min        373.000000
# 25%       2592.000000
# 50%       4770.000000
# 75%       6900.500000
# max      10154.000000
# Name: Paper Ticket, dtype: float64
